# %%
import pandas as pd

# %%
df = pd.read_csv("../data/groundtruth/csv/train_big_size_A_B_E_K_WH_WB.csv")

# %%
# class distribution
df['Label'].value_counts().sort_index().plot(kind='bar')
# Out:
# <Axes: xlabel='Label'>

# %%
df.head()
# Out:
#                      Image    x1    y1    x2    y2  Label
# 0  L_07_05_16_DSC00126.JPG  2488   357  2520   427      3
# 1  L_07_05_16_DSC00126.JPG  1707   446  1746   471      3
# 2  L_07_05_16_DSC00127.JPG  2612  2314  2641  2361      3
# 3  L_07_05_16_DSC00127.JPG  1793  2450  1843  2475      3
# 4  L_07_05_16_DSC00150.JPG  1492  1381  1586  1441      2

# %%
import matplotlib.pyplot as plt
import matplotlib.patches as patches

def show_image_with_boxes(image_path, boxes):
    fig, ax = plt.subplots(1)
    img = plt.imread(image_path)
    ax.imshow(img)

    for box in boxes:
        x1, y1, x2, y2, label = box
        width = x2 - x1
        height = y2 - y1
        rect = patches.Rectangle((x1, y1), width, height, linewidth=1, edgecolor='r', facecolor='none')
        ax.add_patch(rect)
        ax.text(x1, y1, label, color='white', fontsize=12, bbox=dict(facecolor='red', alpha=0.5))

    plt.show()

# %%
# Show the first 5 images with bounding boxes
for i in range(5):
    image_path = f"../data/train/{df.iloc[i]['Image']}"
    boxes = df.iloc[i][['x1', 'y1', 'x2', 'y2', 'Label']].values.reshape(-1, 5)
    show_image_with_boxes(image_path, boxes)
